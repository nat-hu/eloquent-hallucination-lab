# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

# CSV-Datei laden
df = pd.read_csv('/content/drive/MyDrive/Master Project-Hallucination/Group2_results/detection_task/analysis/analysis_se_narjes_prompt - results_gemma_se_vnarjes_trial.csv')


# List of prediction columns
prediction_columns = ["prediction gemma", "prediction gpt 3.5"]

# Funktion zur Berechnung der Metriken
def calculate_metrics(y_true, y_pred):
    metrics = {
        "accuracy": accuracy_score(y_true, y_pred),
        "f1_score": f1_score(y_true, y_pred, average='weighted'),
        "precision": precision_score(y_true, y_pred, average='weighted'),
        "recall": recall_score(y_true, y_pred, average='weighted'),
        "classification_report": classification_report(y_true, y_pred)
    }
    return metrics

# Bericht für jede Prediction-Spalte erstellen
for column in prediction_columns:
    metrics = calculate_metrics(df['label'], df[column])
    print(f"Metrics for {column}:")
    print(f"Accuracy: {metrics['accuracy']}")
    print(f"F1 Score: {metrics['f1_score']}")
    print(f"Precision: {metrics['precision']}")
    print(f"Recall: {metrics['recall']}")
    print(f"Classification Report:\n{metrics['classification_report']}")
    print("\n")
# Out:
# Metrics for prediction gemma:
# Accuracy: 0.65
# F1 Score: 0.5808777429467085
# Precision: 0.7861111111111112
# Recall: 0.65
# Classification Report:
#               precision    recall  f1-score   support
#
#         hyp1       1.00      0.22      0.36         9
#         hyp2       0.61      1.00      0.76        11
#
#     accuracy                           0.65        20
#    macro avg       0.81      0.61      0.56        20
# weighted avg       0.79      0.65      0.58        20
#
#
#
# Metrics for prediction gpt 3.5:
# Accuracy: 0.55
# F1 Score: 0.532
# Precision: 0.5392857142857143
# Recall: 0.55
# Classification Report:
#               precision    recall  f1-score   support
#
#         hyp1       0.50      0.33      0.40         9
#         hyp2       0.57      0.73      0.64        11
#
#     accuracy                           0.55        20
#    macro avg       0.54      0.53      0.52        20
# weighted avg       0.54      0.55      0.53        20

# %%
# Definiere die speziellen Spalten, die du drucken möchtest
columns_to_print = ['id', 'type', 'label', 'prediction gemma', 'prediction gpt 3.5']

# Wähle nur die speziellen Spalten aus
selected_columns_df = df[columns_to_print]


# Ganze Tabelle ausdrucken
print(selected_columns_df.to_string())
# Out:
#     id          type label prediction gemma prediction gpt 3.5
# 0    0        number  hyp2             hyp2               hyp2
# 1    1       natural  hyp1             hyp2               hyp2
# 2    2  named entity  hyp2             hyp2               hyp2
# 3    3      addition  hyp2             hyp2               hyp1
# 4    4      negation  hyp1             hyp1               hyp1
# 5    5        gender  hyp2             hyp2               hyp2
# 6    6       antonym  hyp2             hyp2               hyp2
# 7    7      negation  hyp1             hyp1               hyp1
# 8    8      addition  hyp2             hyp2               hyp1
# 9    9        number  hyp2             hyp2               hyp2
# 10  10       natural  hyp1             hyp2               hyp1
# 11  11      addition  hyp2             hyp2               hyp1
# 12  12      addition  hyp2             hyp2               hyp2
# 13  13  named entity  hyp1             hyp2               hyp2
# ...
