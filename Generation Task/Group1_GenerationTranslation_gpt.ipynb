# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.19.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.23.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.1)

# %%
# Imports
import json
import re
import os
import numpy as np
import pandas as pd
from openai import OpenAI
from datasets import load_dataset

from google.colab import userdata
client = OpenAI(api_key=userdata.get('OPEN_API_KEY_IR'))

# %% [markdown]
# # Dataset

# %%
#load the data for all languages
data = load_dataset("Eloquent/HalluciGen-Translation", "test_generation")

print(data.keys())

data_de_en = data['test_generation_de_en'].to_pandas()
data_en_de = data['test_generation_en_de'].to_pandas()
data_fr_en = data['test_generation_fr_en'].to_pandas()
data_en_fr = data['test_generation_en_fr'].to_pandas()

display(data_de_en.head())
display(data_en_de.head())
# Out:
# dict_keys(['test_generation_de_en', 'test_generation_en_de', 'test_generation_fr_en', 'test_generation_en_fr'])
#    id langpair                                             source
# 0   0    de-en  In Ländern ist das Anbieten von Luxus-Gästehäu...
# 1   1    de-en  Dies ist in Großbritannien gängige Praxis, abe...
# 2   2    de-en  „Auf Grundlage dieses Fossils lässt sich sagen...
# 3   3    de-en  Wir werden niemals ein Auto überholen, einen B...
# 4   4    de-en  Ein Minenabwehrschiff der Avenger-Klasse, das ...
#    id langpair                                             source
# 0   0    en-de  He graduated from the College of Arts & Scienc...
# 1   1    en-de  Most are independent nations, or associated wi...
# 2   2    en-de  But there are a lot of things about birds that...
# 3   3    en-de  The police had trouble using their speed radar...
# 4   4    en-de  "The Giza Plateau, or ""Giza Necropolis"" in t...

# %% [markdown]
# ## Generate Data

# %%
def generate_hypothesis(source, target_language):

  answer_format = {"hyp+": "", "hyp-": ""}

  system_msg = "You are a text generator for translation"

  # prompt for translation generation task
  user_msg = f'''Your task is to generate two translation hypothesis given the 'src' below.
      The first translation labelled as 'hyp+' should be supported by 'src' and the second translation labelled as 'hyp-' should not be supported by 'src'.
      Provide the result in the following format: {answer_format}. Target language: {target_language}

       Src: {source}

       Result:
       '''

  response = client.chat.completions.create(model="gpt-3.5-turbo",
                                        messages=[{"role": "system", "content": system_msg},
                                         {"role": "user", "content": user_msg}])

  #print("Gen text: ", outputs[0]["generated_text"][len(prompt):])
  generated_translation = response.choices[0].message.content
  #print(generated_translation)

  return generated_translation

# %% [markdown]
# ## Save Data as csv file

# %%
def extract_json_data(result_text):
    # Find the start and end indices of the JSON data
    start_index = result_text.find('{')
    end_index = result_text.find('}') + 1  # Add 1 to include the closing brace

    # Extract the JSON data from the string
    result_text = result_text[start_index:end_index]
    #print("result text: ", result_text)

    # Replace single quotes used as delimiters with double quotes
    result_text = json.loads(result_text.replace("'", "\""))
    return result_text

# %%
#save results
def save_results(target_language, df, csv_filename):
    skipped_rows = []
    # Split DataFrame into chunks of 10 rows
    chunks = np.array_split(df, len(df) // 10 if len(df) % 10 == 0 else len(df) // 10 + 1)

    for chunk in chunks:
        # Iterate through each row in the chunk
        for index, row in chunk.iterrows():
            source = row['source']

            try:
                # Generate translation
                result = generate_hypothesis(source, target_language)
                extracted_hyp = extract_json_data(result)

                hyp_support = extracted_hyp['hyp+']
                #print(hyp_support)
                hyp_hallu = extracted_hyp['hyp-']
                #print(hyp_hallu)
                #print('source:',source)

                # Update DataFrame with new values
                chunk.at[index, 'hyp+'] = hyp_support
                chunk.at[index, 'hyp-'] = hyp_hallu
                #chunk.at[index, 'prompt'] = prompt
            except:
                print(f"Skipping row {index} due to error in data extraction.")
                skipped_rows.append(index)
                continue

        # Append chunk to CSV file
        if not os.path.isfile(csv_filename):
            chunk.to_csv(csv_filename, mode='w', header=True, index=False)
        else:
            chunk.to_csv(csv_filename, mode='a', header=False, index=False)

        # Load CSV file
        df = pd.read_csv(csv_filename)
        #display(df)
    return skipped_rows

# %%
def fix_skipped_rows(target_language, df, csv_filename, skipped_rows):
    skipped_rows2 = []
    for index in skipped_rows:
        row = df.loc[index]

        source = row['source']

        try:
            result = generate_hypothesis(source, target_language)
            # Find the start and end indices of the JSON data
            start_index = result.find('{')
            end_index = result.find('}') + 1
            result_text = result[start_index:end_index]
            result_text = result_text.replace('"', "'").replace("{'hyp+': '", '{"hyp+": "').replace(".', 'hyp-': '", '.", "hyp-": "').replace(".',\n'hyp-': '", '.",\n"hyp-": "').replace(".', \n'hyp-': '", '.", \n"hyp-": "').replace("'}", '"}')
            print("result text ", result_text)
            #print("result text ", result_text)
            extracted_hyp = json.loads(result_text)
            df.at[index, 'hyp+'] =  extracted_hyp['hyp+']
            df.at[index, 'hyp-'] =  extracted_hyp['hyp-']
        except Exception as e:
            print(f"Skipping row {index} due to error in data extraction.")
            skipped_rows2.append(index)
            continue

    df.to_csv(csv_filename, index=False)
    return skipped_rows2

# %%
data_de_en.loc[10]
# Out:
# id                                                         10
# langpair                                                de-en
# source      "Perry erklärte, er werde "nach Texas zurückke...
# Name: 10, dtype: object

# %%
data_de_en.loc[10].values
# Out:
# array([10, 'de-en',
#        '"Perry erklärte, er werde "nach Texas zurückkehren, um das Ergebnis der Vorwahl von heute Abend auszuwerten und zu entscheiden, ob es in diesem Rennen einen weiterführenden Weg für mich gibt"", aber sagte später, er werde im Rennen bleiben und bei den Vorwahlen in South Carolina am 21. Januar antreten."'],
#       dtype=object)

# %% [markdown]
# # Translation German - English

# %%
csv_filename = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_de_en.csv"

skipped_rows_de_en = save_results("English", data_de_en, csv_filename)
# Out:
# Skipping row 9 due to error in data extraction.
# Skipping row 10 due to error in data extraction.
# Skipping row 16 due to error in data extraction.
# Skipping row 31 due to error in data extraction.
# Skipping row 41 due to error in data extraction.
# Skipping row 44 due to error in data extraction.
# Skipping row 60 due to error in data extraction.
# Skipping row 64 due to error in data extraction.
# Skipping row 67 due to error in data extraction.
# Skipping row 79 due to error in data extraction.
# Skipping row 84 due to error in data extraction.
# Skipping row 85 due to error in data extraction.

# %%
skipped_rows_de_en
# Out:
# [9, 10, 16, 31, 41, 44, 60, 64, 67, 79, 84, 85]

# %%
df_results_de_en = pd.read_csv("/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_de_en.csv")

# %%
csv_filename2 = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_de_en_fixed.csv"

skipped_rows_de_en = fix_skipped_rows("English", df_results_de_en, csv_filename2, skipped_rows_de_en)
# Out:
# result text  {"hyp+": "In the last 20 years, the selection in Uptown Charlotte has grown exponentially.", "hyp-": "Uptown Charlotte has not experienced significant growth in the past two decades."}
# result text  {"hyp+": "Perry stated that he will return to Texas to assess the results of tonight's primary and decide if there is a viable path forward for him in this race, but later said he will stay in the race and compete in the South Carolina primaries on January 21.", "hyp-": "Perry announced he is dropping out of the race and will not be participating in any future primaries."}
# result text  {"hyp+": "The clearance height under the bridge is 15 meters. The construction work was completed in August 2011, but the approval for traffic was only given in March 2017.", "hyp-": "The bridge clearance height is 20 meters. The construction work finished in October 2010, and the traffic approval was granted in December 2016."}
# result text  {"hyp+": "In 2009, Coolidge played the dramatic role of 'Geneviève McDonagh.'', 'hyp-': 'Coolidge played a comedic role in 2009."}
# Skipping row 31 due to error in data extraction.
# result text  {"hyp+": "In 2009, Coolidge played the dramatic role of 'Geneviève McDonagh.'', 'hyp-': 'In 2009, Coolidge sang a song in a musical production."}
# Skipping row 41 due to error in data extraction.
# result text  {"hyp+": "The next version was created in 1986 by Robert Fuller\'s brother Ron.", "hyp-": "The previous version was created in 1986 by Robert Fuller\'s brother Ron."}
# Skipping row 44 due to error in data extraction.
# result text  {"hyp+": "The PBS show won more than two dozen Emmy Awards and its runtime is only shorter than Sesame Street and Mister Rogers' Neighborhood.", "hyp-": "The PBS show won more than two dozen Emmy Awards, surpassing the runtime of Sesame Street and Mister Rogers' Neighborhood."}
# result text  {"hyp+": "The total area of Turkey, including the lakes, covers 783,562 square kilometers (300,948 square miles), with 755,688 square kilometers (291,773 square miles) in Southwest Asia and 23,764 square kilometers (9,174 square miles) in Europe.", "hyp-": "Turkey's territory includes 783 lakes spanning 562 square kilometers, with 755 square kilometers in South Asia and 23 square kilometers in Europe."}
# result text  {"hyp+": "Reid managed to drive New Zealand's A1GP car Black Beauty over the bridge seven times at speeds exceeding 160 km/h.", "hyp-": "Reid was unable to handle the high speeds of over 160 km/h and lost control of the A1GP car Black Beauty while driving over the bridge."}
# result text  {"hyp+": "Miranda quotes Voltaire: 'If we do not find something pleasant at least, we will find something new' and gazes longingly at Oscar.", "hyp-": "Miranda cites Voltaire as saying: 'If we do not find something pleasant at least, we will find something new' and looks at Oscar with disdain."}
# result text  {"hyp+": "The Swiss teacher Jürgen Reichen (progressive education) established this 'Writing to Read' method in 1982.", "hyp-": "The Swiss teacher Jürgen Reichen (progressive education) was known for his work in mathematics education."}
# result text  {"hyp+": "If `` R '' is the corresponding equivalence relation over every trivial component of `` U ``.", "hyp-": "If `` R '' is not the corresponding equivalence relation over every trivial component of `` U ''. "}

# %%
skipped_rows_de_en
# Out:
# [31, 41, 44]

# %%
def fix_skipped_rows_manual(target_language, df, skipped_rows):
    for index in skipped_rows:
        row = df.loc[index]

        source = row['source']

        result = generate_hypothesis(source, target_language)
        # Find the start and end indices of the JSON data
        start_index = result.find('{')
        end_index = result.find('}') + 1
        result_text = result[start_index:end_index]
        #result_text = result_text.replace('"', "'").replace("{'hyp+': '", '{"hyp+": "').replace(".', 'hyp-': '", '.", "hyp-": "').replace(".',\n'hyp-': '", '.",\n"hyp-": "').replace(".', \n'hyp-': '", '.", \n"hyp-": "').replace("'}", '"}')
        print("result text ", result_text)
        #print("result text ", result_text)
        #extracted_hyp = json.loads(result_text)
        #df.at[index, 'hyp+'] =  extracted_hyp['hyp+']
        #df.at[index, 'hyp-'] =  extracted_hyp['hyp-']


    #df.to_csv(csv_filename, index=False)

# %%
fix_skipped_rows_manual("English", df_results_de_en, skipped_rows_de_en)
# Out:
# result text  {'hyp+': 'In 2009, Coolidge played the dramatic role of “Geneviève McDonagh.”', 'hyp-': 'Coolidge played a comedic role in 2009.'}
# result text  {'hyp+': 'In 2009, Coolidge played the dramatic role of "Geneviève McDonagh."', 'hyp-': 'In 2009, Coolidge directed the dramatic film "Geneviève McDonagh".'}
# result text  {'hyp+': 'The next version was created in 1986 by Robert Fuller's brother Ron.', 'hyp-': 'The following edition was designed by Robert Fuller in 1986.'}

# %% [markdown]
# # Translation English - German

# %%
csv_filename = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_en_de.csv"

skipped_rows_en_de = save_results("German", data_en_de, csv_filename)
# Out:
# Skipping row 4 due to error in data extraction.
# Skipping row 5 due to error in data extraction.
# Skipping row 10 due to error in data extraction.
# Skipping row 21 due to error in data extraction.
# Skipping row 33 due to error in data extraction.
# Skipping row 45 due to error in data extraction.
# Skipping row 57 due to error in data extraction.
# Skipping row 62 due to error in data extraction.
# Skipping row 89 due to error in data extraction.
# Skipping row 98 due to error in data extraction.

# %%
df_results_en_de = pd.read_csv("/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_en_de.csv")

# %%
csv_filename2 = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_en_de_fixed.csv"

skipped_rows_en_de = fix_skipped_rows("German", df_results_en_de, csv_filename2, skipped_rows_en_de)
# Out:
# result text  {"hyp+": "Das Gizeh-Plateau oder die ''Gizeh-Nekropole'' im ägyptischen Tal der Toten enthält mehrere Pyramiden (von denen die Pyramide die größte ist), mehrere kleine Gräber, mehrere Tempel und die große Sphinx.", "hyp-": "Der Gizeh-Plateau oder die 'Gizeh-Nekropole' im ägyptischen Tal der Toten enthält keine Pyramiden, sondern nur kleine Tempel und Gräber."}
# result text  {"hyp+": "Der Premierminister Stephen Harper hat zugestimmt, das Regierungsgesetz 'Clean Act' zur Überprüfung an einen Ausschuss aller Parteien zu senden, bevor es zur zweiten Lesung kommt, nach einem 25-minütigen Treffen am Dienstag mit dem NDP-Führer Jack Layton im PMO.", "hyp-": "Der Premierminister Stephen Harper hat entschieden, das Regierungsgesetz 'Clean Act' ohne jegliche Überprüfung durch ein allparteiliches Komitee zur zweiten Lesung zu schicken, nach einem 25-minütigen Treffen am Dienstag mit dem NDP-Führer Jack Layton im PMO."}
# result text  {"hyp+": "Am 24. September 1759 unterzeichnete Arthur Guinness einen 9.000-jährigen Mietvertrag für die St. James' Gate Brauerei in Dublin, Irland.", "hyp-": "Arthur Guinness unterschrieb am 24. September 1759 einen 9.000-jährigen Mietvertrag für die Brauerei in Schottland."}
# result text  {"hyp+": "Am 15. August 1940 griffen die Alliierten Südfrankreich an, die Invasion wurde als 'Operation Dragoon' bezeichnet.", "hyp-": "Am 15. August 1940 griffen die Achsenmächte Südfrankreich an, die Invasion wurde 'Operation Dragoon' genannt."}
# result text  {"hyp+": "Es wurde von Willard Mack inszeniert und basiert auf einem Theaterstück von 1917 mit dem Titel 'Tiger Rose' von George Fitzmaurice.", "hyp-": "Es handelt sich um einen Film aus dem Jahr 1930."}
# result text  {"hyp+": "Die Art wurde erstmals im Jahr 1846 vom Botaniker Stephan Endlicher offiziell beschrieben, als Teil des Werkes 'Irideae Plantae Preissianae' von Johann Georg Christian Lehmann.", "hyp-": "Die Art wurde nicht von Johann Georg Christian Lehmann im Jahr 1846 offiziell beschrieben, sondern von einem anderen Botaniker."}
# result text  {"hyp+": "Für Australier ist die Idee von einem 'Flat White'-Kaffee fremd.", "hyp-": "Australier lieben starken Kaffee ohne Milch."}
# result text  {"hyp+": "Obwohl das Wort 'Zigeuner' weit verbreitet ist, insbesondere unter Nicht-Roma, wird es oft als beleidigend angesehen aufgrund seiner Verbindungen mit negativen Stereotypen und ungenauen Vorstellungen von Romani-Leuten.", "hyp-": "Obwohl es weit verbreitet ist, wird das Wort 'Zigeuner' von Romani-Leuten nicht als beleidigend angesehen."}
# result text  {"hyp+": "Schließlich, nach vier vollen Stunden meines Liegens und Starrens darauf, klingelte das Telefon, und irgendwie schaffte ich es, abzuheben, und es war mein Vater, und ich sagte: 'Ich stecke in ernsthaften Schwierigkeiten. Wir müssen etwas tun.'', 'hyp-': 'Nach vier vollen Stunden meines Liegens und Starrens darauf, klingelte das Telefon, und ich schaffte es, abzuheben, und es war nicht mein Vater, sondern meine Mutter, und ich sagte: 'Ich brauche Hilfe. Kannst du kommen?'"}
# Skipping row 89 due to error in data extraction.
# result text  {"hyp+": "Sie sagte: 'Früher hatte ich einen Job, aber ich musste aufhören, weil ich nicht mehr aus dem Haus gehen konnte.'', 'hyp-': 'Sie erzählte mir, dass sie früher einen Job hatte, aber aufgehört hat, weil sie gerne zu Hause bleibt."}
# Skipping row 98 due to error in data extraction.

# %%
fix_skipped_rows_manual("German", df_results_en_de, skipped_rows_en_de)
# Out:
# result text  {'hyp+': 'Und schließlich, nach vollen vier Stunden, in denen ich gelogen und es angestarrt habe, klingelte das Telefon, und irgendwie schaffte ich es aufzuheben, und es war mein Vater, und ich sagte: "Ich bin in ernsthaften Schwierigkeiten. Wir müssen etwas unternehmen."', 'hyp-': 'Nach vier vollen Stunden des Lügens und Starrens klingelte das Telefon und als ich abhob, war es meine Mutter, und ich sagte: "Alles in Ordnung hier."'}
# result text  {'hyp+': 'Sie sagte: "Früher hatte ich einen Job, aber ich musste aufhören, weil ich nicht aus dem Haus gehen konnte."', 'hyp-': 'Sie erzählte, dass sie immer Arbeit hatte und gerne zur Arbeit ging, bevor sie nicht mehr aus dem Haus gehen konnte.'}

# %% [markdown]
# # Translation French - English

# %%
csv_filename = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_fr_en.csv"

skipped_rows_fr_en = save_results("English", data_fr_en, csv_filename)
# Out:
# Skipping row 11 due to error in data extraction.
# Skipping row 23 due to error in data extraction.
# Skipping row 32 due to error in data extraction.
# Skipping row 35 due to error in data extraction.
# Skipping row 36 due to error in data extraction.
# Skipping row 42 due to error in data extraction.
# Skipping row 48 due to error in data extraction.
# Skipping row 50 due to error in data extraction.
# Skipping row 51 due to error in data extraction.
# Skipping row 58 due to error in data extraction.
# Skipping row 60 due to error in data extraction.
# Skipping row 71 due to error in data extraction.
# Skipping row 74 due to error in data extraction.
# Skipping row 75 due to error in data extraction.
# Skipping row 83 due to error in data extraction.
# Skipping row 86 due to error in data extraction.
# Skipping row 88 due to error in data extraction.
# Skipping row 89 due to error in data extraction.
# Skipping row 90 due to error in data extraction.

# %%
df_results_fr_en = pd.read_csv("/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_fr_en.csv")
csv_filename2 = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_fr_en_fixed.csv"

skipped_rows_fr_en = fix_skipped_rows("English", df_results_fr_en, csv_filename2, skipped_rows_fr_en)
# Out:
# result text  {"hyp+": "The issue began on January 1st when dozens of local residents started complaining to the Obanazawa post office that they had not received their traditional and regular New Year's cards.", "hyp-": "The problem started on December 25th when a few local residents complained to the Obanazawa post office that they had not received their Christmas cards."}
# result text  {"hyp+": "The chef became friends with the assistant.", "hyp-": "The chef fired the assistant."}
# result text  {"hyp+": "Octavius Warre Malet's second daughter, Alice Anna Catherine, married Thomas at the British Consulate in Cologne on June 24, 1852.", "hyp-": "Alice Anna Catherine, the second daughter of Octavius Warre Malet, married Thomas at the French Consulate in Cologne on June 24, 1852."}
# result text  {"hyp+": "In 2012, Gil joined the TV program - Remake of the Salvador-Royales-Films 'Mundo Man ay Magunaw' in the role of Jennifer la Pena.", "hyp-": "Gil was a contestant on a cooking show in 2012."}
# result text  {"hyp+": "In 'Detection Unlimited', a detective novel written by Georgette Heyer, a character is compared to Armstrong.", "hyp-": "In 'Detection Unlimited', a crime fiction book written by Georgette Heyer, a character is compared to Armstrong."}
# result text  {"hyp+": "The following piece was created by Ron's brother, Robert Fuller, in 1986.", "hyp-": "The following piece was created by Ron himself in 1986."}
# result text  {"hyp+": "David Allan Coe joined Warren Haynes' touring and recording group in 1980, at the age of 20.", "hyp-": "David Allan Coe quit the music industry to pursue a career in finance in 1980, at the age of 20."}
# result text  {"hyp+": "The surface area of Turkey, including lakes, is 783,562 square kilometers, of which 755,688 square kilometers are in Southwest Asia and 23,764 square kilometers are in Europe.", "hyp-": "Turkey is a landlocked country surrounded by oceans on all sides."}
# result text  {"hyp+": "The total area of Turkey, including lakes, is 783,562 square kilometers, with 755,688 square kilometers in Southwest Asia and 23,764 square kilometers in Europe.", "hyp-": "The total area of Turkey, including lakes, is 783,562 square kilometers, with 755,688 square kilometers in Europe and 23,764 square kilometers in Southwest Asia."}
# result text  {"hyp+": "The 35 mm format is actually, and it is quite disconcerting, 36 mm wide by 24 mm high.", "hyp-": "The 35 mm format is actually smaller than 36 mm by 24 mm in size."}
# result text  {"hyp+": "The 35mm format is actually, and it is quite disconcerting, 36mm wide by 24mm high.", "hyp-": "The 35mm format is actually 36mm wide and 24mm high in size."}
# result text  {"hyp+": "Mahatma Gandhi said: 'Spiritual education is the evolution of the mind', but today, we are not making any real progress.", "hyp-": "Mahatma Gandhi believed that spiritual education is not important for the evolution of the mind."}
# result text  {"hyp+": "Of the twelve stories included, six had already been published in the author\'s first collection, 'Evening News'.", "hyp-": "The stories in the second collection of the author were completely new and had not been previously published."}
# Skipping row 74 due to error in data extraction.
# result text  {"hyp+": "Quentin Collins, Ed Griffin, in 'House of Despair', tells how the residents of Collinsport have not forgotten how 'the winter girl disappeared inexplicably.'', 'hyp-': 'Quentin Collins and Ed Griffin, in 'House of Despair', reveal the mysterious disappearance of the winter girl in Collinsport."}
# Skipping row 75 due to error in data extraction.
# result text  {"hyp+": "M. Cave made the highest bid for Mr. Payne's belongings.", "hyp-": "M. Cave made the lowest bid for Mr. Payne's belongings."}
# result text  {"hyp+": "The admiral rejected the request until it was too late and the 'Conte di Cavour' had to use a deeper sandbank on November 12 at 4:30 AM.", "hyp-": "The admiral accepted the request and the 'Conte di Cavour' safely navigated through the shallow sandbank on November 12 at 4:30 AM."}
# result text  {"hyp+": "His name, 'Afolabi', means 'Born into wealth'. His nickname in Nigeria is Robocop because of his stiff movements.", "hyp-": "Afolabi is known as Robocop in Nigeria due to his flexible dance moves."}
# result text  {"hyp+": "Daniil Ostrogski also states that Dmytro is the father of Bilinsky, also known as 'Danylo Dmytrovych.'', 'hyp-': 'Daniil Ostrogski denies that Dmytro is the father of Bilinsky, also known as 'Danylo Dmytrovych.'"}
# Skipping row 89 due to error in data extraction.
# result text  {"hyp+": "This requires continuous monitoring of actual partial pressures over time and, for maximum efficiency, real-time computer processing by the diver's decompression computer.", "hyp-": "This requires the divers to manually adjust the pressure levels during the dive for maximum safety."}

# %%
fix_skipped_rows_manual("English", df_results_fr_en, skipped_rows_fr_en)
# Out:
# result text  {'hyp+': 'Of the twelve stories included, six had already been published in the author's first collection, "Evening News".', 'hyp-': 'The stories are all new and have never been published before.'}
# result text  {'hyp+': 'Quentin Collins, Ed Griffin, in "House of Despair", recounts how the residents of Collinsport have not forgotten how "the winter girl inexplicably disappeared."', 'hyp-': 'Quentin Collins, Ed Griffin, in "House of Despair", recounts how the residents of Collinsport have not forgotten the mysterious disappearance of a young girl in the winter.'}
# result text  {'hyp+': 'Daniil Ostrogski also states that Dmytro is the father of Bilinsky, also known as "Danylo Dmytrovych."', 'hyp-': 'Daniil Ostrogski claims that Bilinsky is the father of Dmytro, also known as "Danylo Dmytrovych."'}

# %% [markdown]
# # Translation English - French

# %%
csv_filename = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_en_fr.csv"

skipped_rows_en_fr =  save_results("French", data_en_fr, csv_filename)
# Out:
# Skipping row 0 due to error in data extraction.
# Skipping row 1 due to error in data extraction.
# Skipping row 2 due to error in data extraction.
# Skipping row 4 due to error in data extraction.
# Skipping row 6 due to error in data extraction.
# Skipping row 8 due to error in data extraction.
# Skipping row 9 due to error in data extraction.
# Skipping row 10 due to error in data extraction.
# Skipping row 11 due to error in data extraction.
# Skipping row 13 due to error in data extraction.
# Skipping row 14 due to error in data extraction.
# Skipping row 15 due to error in data extraction.
# Skipping row 16 due to error in data extraction.
# Skipping row 17 due to error in data extraction.
# Skipping row 18 due to error in data extraction.
# Skipping row 19 due to error in data extraction.
# Skipping row 20 due to error in data extraction.
# Skipping row 21 due to error in data extraction.
# Skipping row 22 due to error in data extraction.
# Skipping row 24 due to error in data extraction.
# Skipping row 26 due to error in data extraction.
# Skipping row 27 due to error in data extraction.
# Skipping row 29 due to error in data extraction.
# Skipping row 30 due to error in data extraction.
# Skipping row 31 due to error in data extraction.
# Skipping row 32 due to error in data extraction.
# Skipping row 34 due to error in data extraction.
# Skipping row 37 due to error in data extraction.
# Skipping row 38 due to error in data extraction.
# Skipping row 39 due to error in data extraction.
# Skipping row 41 due to error in data extraction.
# Skipping row 44 due to error in data extraction.
# Skipping row 45 due to error in data extraction.
# Skipping row 49 due to error in data extraction.
# Skipping row 50 due to error in data extraction.
# Skipping row 51 due to error in data extraction.
# Skipping row 52 due to error in data extraction.
# Skipping row 53 due to error in data extraction.
# Skipping row 54 due to error in data extraction.
# Skipping row 55 due to error in data extraction.
# Skipping row 58 due to error in data extraction.
# Skipping row 60 due to error in data extraction.
# Skipping row 61 due to error in data extraction.
# Skipping row 62 due to error in data extraction.
# Skipping row 63 due to error in data extraction.
# Skipping row 64 due to error in data extraction.
# Skipping row 65 due to error in data extraction.
# Skipping row 69 due to error in data extraction.
# Skipping row 70 due to error in data extraction.
# Skipping row 71 due to error in data extraction.
# Skipping row 72 due to error in data extraction.
# Skipping row 75 due to error in data extraction.
# Skipping row 77 due to error in data extraction.
# Skipping row 78 due to error in data extraction.
# Skipping row 80 due to error in data extraction.
# Skipping row 81 due to error in data extraction.
# Skipping row 82 due to error in data extraction.
# Skipping row 84 due to error in data extraction.
# Skipping row 86 due to error in data extraction.
# Skipping row 88 due to error in data extraction.
# Skipping row 89 due to error in data extraction.
# Skipping row 90 due to error in data extraction.
# Skipping row 98 due to error in data extraction.
# Skipping row 99 due to error in data extraction.

# %%
df_results_en_fr = pd.read_csv("/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_en_fr.csv")
csv_filename2 = "/content/drive/MyDrive/Master Project-Hallucination/Group1_results/Generation_task/gpt/results_gpt_en_fr_fixed.csv"

skipped_rows_en_fr = fix_skipped_rows("French", df_results_en_fr, csv_filename2, skipped_rows_en_fr)
# Out:
# result text  {"hyp+": "Né dans la capitale croate, Bobek a acquis la renommée en jouant pour le Partizan de Belgrade.", "hyp-": "Bobek est né en Serbie et a déménagé à Zagreb où il est devenu célèbre."}
# result text  {"hyp+": "Utiliser des applications de navigation GPS peut être le moyen le plus facile et le plus pratique de se déplacer lorsque l'on est en dehors de son pays d'origine.", "hyp-": "Les applications de navigation GPS sont rarement utiles en voyage à l'étranger."}
# result text  {"hyp+": "Seuls les effets du catastrophisme, et non de la dépression et de la peur, étaient conditionnels des séances hebdomadaires régulières de PA.", "hyp-": "Seuls les effets de la dépression et de la peur, pas le catastrophisme, étaient conditionnels des séances hebdomadaires régulières de PA."}
# result text  {"hyp+": "Les étoiles émettent de la lumière et de la chaleur en raison de l'énergie produite lorsque les atomes sont fusionnés pour former des éléments plus lourds.", "hyp-": "Les étoiles émettent du son et du froid à cause de la fusion des atomes."}
# result text  {"hyp+": "Le président américain George W. a salué l'annonce.", "hyp-": "La président américain George W. a critiqué l'annonce."}
# result text  {"hyp+": "Les dépenses de guerre de l'impérialisme américain dans la conquête ont été payées par le peuple philippin lui-même.", "hyp-": "Les dépenses de guerre de l'impérialisme américain dans la conquête ont été payées par une autre nation."}
# result text  {"hyp+": "Avec des racines à Running Tours Barcelona et Running Copenhagen à Barcelone et Copenhague, c'est rapidement rejoint par des Running Tours basés à Prague et d'autres.", "hyp-": "Avec des racines à Barcelone, le programme de visites en cours d'exécution comprend également des visites à Copenhague et Prague, ainsi que dans d'autres villes."}
# result text  {"hyp+": "Couchsurfing a été fondé en janvier 2004 après que le programmeur informatique Casey Fenton ait trouvé un vol bon marché pour l'Islande mais n'avait pas de logement.", "hyp-": "Couchsurfing a été créé en février 2004 après que Casey Fenton, plombier de profession, ait trouvé un vol bon marché pour la Norvège mais n'avait pas de logement."}
# result text  {"hyp+": "Ainsi, un permis arrière-pays pour n'importe quelle date de départ en mai sera disponible le 1er janvier.", "hyp-": "Par conséquent, un permis de pêche pour toute date de départ en mai sera disponible le 1er janvier."}
# result text  {"hyp+": "La société de gestion du groupe, HK Management Inc., n'a donné aucune raison initiale lorsqu'elle a annulé le 20 septembre, mais a blâmé des raisons logistiques dès le lendemain.", "hyp-": "Le groupe de musique a annulé le concert le 20 septembre en raison de problèmes techniques."}
# result text  {"hyp+": "Plusieurs personnes ont vérifié la découverte en utilisant du matériel et des logiciels différents au début de février et elle a été annoncée mardi.", "hyp-": "Il n'y a eu aucune vérification de la découverte et aucune annonce n'a été faite."}
# result text  {"hyp+": "Le 24 septembre 1759, Arthur Guinness a signé un bail de 9 000 ans pour la brasserie St James' Gate à Dublin, en Irlande.", "hyp-": "Arthur Guinness a signé un bail de courte durée pour la brasserie St James' Gate à Dublin."}
# result text  {"hyp+": "Depuis sa création, The Onion est devenu un véritable empire de la parodie de l'actualité, avec une édition imprimée, un site web qui a attiré 5 000 000 de visiteurs uniques au mois d'octobre, des annonces personnelles, un réseau d'actualités 24 heures sur 24, des podcasts et un atlas mondial récemment lancé appelé Our Dumb World.", "hyp-": "The Onion est un réseau de restaurants de fast-food populaire dans le monde entier."}
# result text  {"hyp+": "Le problème a commencé le 1er janvier lorsque des dizaines de résidents locaux ont commencé à se plaindre au bureau de poste d'Obanazawa qu'ils n'avaient pas reçu leurs cartes traditionnelles et régulières du Nouvel An.", "hyp-": "La situation a commencé en février lorsque des centaines de touristes ont commencé à se plaindre au bureau de poste d'Obanazawa qu'ils n'avaient pas reçu leurs cartes de Saint-Valentin."}
# result text  {"hyp+": "Depuis que le gouvernement fédéral est intervenu pour prendre en charge le financement de l'hôpital de Mersey à Devonport, en Tasmanie, le gouvernement de l'État et certains députés fédéraux ont critiqué cet acte comme une manoeuvre pré-électorale en prévision des élections fédérales prévues pour novembre.", "hyp-": "Depuis que le gouvernement fédéral est intervenu pour prendre en charge le financement de l'hôpital de Mersey à Devonport, en Tasmanie, le gouvernement de l'État et certains députés fédéraux ont salué cette initiative comme un geste nécessaire pour améliorer les services de santé."}
# result text  {"hyp+": "Curtis Cooper, un mathématicien et professeur d'informatique à l'Université du Missouri central, a découvert le plus grand nombre premier connu à ce jour le 25 janvier.", "hyp-": "Curtis Cooper, enseignant en histoire à l'Université de Californie du Sud, a trouvé le plus grand nombre premier jusqu'à présent le 25 janvier."}
# result text  {"hyp+": "Le joueur de 21 ans, Jesus, a rejoint Manchester City en janvier 2017 en provenance du club brésilien Palmeiras pour un montant estimé à 27 millions de livres.", "hyp-": "Jésus, âgé de 21 ans, a été transféré à Manchester City en 2017 à l'âge de 27 ans, en provenance du club brésilien Palmeiras pour une somme reportée de 27 millions de livres."}
# result text  {"hyp+": "Les fouilles aux points de contrôle de sécurité sont devenues bien plus intrusives à l'époque postérieure au 11 septembre 2001.", "hyp-": "Les fouilles aux points de contrôle de sécurité sont devenues moins intrusives à l'époque postérieure au 11 septembre 2001."}
# result text  {"hyp+": "Le pont est prévu d'être pleinement opérationnel en septembre 2017, lorsque les postes de contrôle douaniers brésiliens devraient être terminés.", "hyp-": "Le tunnel sera achevé en novembre 2017, une fois que les postes de contrôle douaniers brésiliens seront opérationnels."}
# result text  {"hyp+": "Le président américain George W. Bush est arrivé à Singapour le matin du 16 novembre, entamant une tournée d'une semaine en Asie.", "hyp-": "Le président américain George W. Bush est né à Singapour le matin du 16 novembre, entamant une tournée d'une semaine en Asie."}
# result text  {"hyp+": "Les politiques d'annulation varient, mais à la fin du mois de mars, la plupart des politiques d'annulation basées sur le coronavirus ne s'étendent pas à juillet 2020, date à laquelle les Jeux olympiques étaient prévus.", "hyp-": "Les politiques d'annulation varient, mais à partir de juillet 2020, les politiques d'annulation basées sur le coronavirus seront plus flexibles."}
# result text  {"hyp+": "Le 17 septembre 1939, la défense polonaise était déjà brisée, et le seul espoir était de battre en retraite et de se réorganiser le long de la tête de pont roumaine.", "hyp-": "En septembre 1939, la défense polonaise avait réussi à contenir l'ennemi et préparait une contre-attaque."}
# result text  {"hyp+": "Le temple d'Artémis à Éphèse a été détruit le 21 juillet 356 av. J.-C. lors d'un incendie criminel commis par Hérostrate.", "hyp-": "Le temple d'Artémis à Éphèse a été détruit suite à un tremblement de terre le 21 juillet 356 av. J.-C."}
# result text  {"hyp+": "Les Jeux paralympiques se dérouleront du 24 août au 5 septembre 2021. Certaines épreuves auront lieu dans d'autres endroits à travers le Japon.", "hyp-": "Les Jeux paralympiques se dérouleront du 24 août au 5 septembre 2021. Toutes les épreuves auront lieu au même endroit au Japon."}
# result text  {"hyp+": "Pendant la saison des pluies (de novembre à mars), le volume d'eau sera plus élevé et les chutes seront plus spectaculaires.", "hyp-": "En été, la neige recouvrira les chutes et les rendra inaccessibles."}
# result text  {"hyp+": "Le plus grand tournoi de l'année a lieu en décembre aux terrains de polo de Las Cañitas.", "hyp-": "En été, les matchs de polo sont très populaires à Las Cañitas."}
# result text  {"hyp+": "De son deuxième mariage avec l'homme d'affaires Babis Lazaridis, elle a un fils, Vasilis.", "hyp-": "Vasilis est le fils de son premier mariage avec Babis Lazaridis."}
# result text  {"hyp+": "Dans un épisode de 1985 de 'The Tonight Show Starring Johnny Carson', Johnny mentionne l'histoire et raconte à son acolyte Ed McMahon l'intrigue.", "hyp-": "Johnny a mentionné l'histoire à Jimmy Fallon lors de l'enregistrement d'une émission de variétés."}
# result text  {"hyp+": "Zedtwitz était président de la Ligue américaine de bridge contractuel en 1932, l'une des organisations dont la fusion a fondé la Ligue américaine de bridge en 1937.", "hyp-": "Zedtwitz était un joueur professionnel de bridge et n'a jamais été impliqué dans la création de la Ligue américaine de bridge en 1937."}
# result text  {"hyp+": "Bala se tient sur un plateau élevé et enneigé, les étés sont chauds, les hivers sont froids.", "hyp-": "Bala reste seul sur une plage de sable chaud, les étés sont doux, les hivers sont doux."}
# result text  {"hyp+": "Comme beaucoup de communautés ethniques en Ouganda, y compris les Langi, les Acholi et les Alur, les Luo ne pratiquent pas la circoncision rituelle des hommes comme initiation.", "hyp-": "Les Luo sont connus pour leur pratique de la circoncision rituelle des hommes comme initiation, contrairement à d'autres communautés ethniques en Ouganda."}
# result text  {"hyp+": "Retzius est né à Stockholm, fils de l'anatomiste Anders Retzius (et petit-fils du naturaliste et chimiste Anders Jahan Retzius).", "hyp-": "Retzius a grandi à Copenhague, où son père était professeur d'astronomie."}
# result text  {"hyp+": "Il a poursuivi sa collaboration avec ESPN pour réaliser deux autres films pour le réseau, `` Wendell Scott '' et `` Herschel''.", "hyp-": "Il a arrêté sa collaboration avec ESPN pour se consacrer à d'autres projets."}
# result text  {"hyp+": "Frank James a rejoint une compagnie sécessionniste recrutée pour l'armée locale de Drew Lobbs et a combattu lors de la bataille de Wilson's Creek en août 1861.", "hyp-": "Frank James était un médecin qui soignait les blessés pendant la bataille de Wilson's Creek en août 1861."}
# result text  {"hyp+": "Le patron intérimaire - René Piccarreto - fils de Loren Piccarreto arrêté en 1988 et libéré en 1994.", "hyp-": "Le patron intérimaire - René Piccarreto - frère de Loren Piccarreto arrêté en 1988 et libéré en 1994."}
# result text  {"hyp+": "Aussi, les groupes ''Air ``, Howie B, Mars IV, Les Négresses Vertes, FFF et Manu Chao ont participé à l'album.", "hyp-": "Les artistes qui ont participé à l'album sont des artistes de différents pays."}
# result text  {"hyp+": "Le pionnier américain John Sutter (1803 - 1880) est arrivé en Alta California avec d'autres colons euro-suisses en août 1839.", "hyp-": "Les premiers colons américains en Californie étaient principalement d'origine française."}
# result text  {"hyp+": "Joe R. Campa Jr. est un ancien marin de la marine des États-Unis, qui a servi en tant que 11e Premier Maître-Chef de la Marine des États-Unis.", "hyp-": "Joe R. Campa Jr. était un astronaute de la NASA, qui a effectué plusieurs missions dans l'espace."}
# result text  {"hyp+": "Johan Ludvig était le fils de Johan Georg Holstein, qui allait devenir lui-même Premier ministre danois, et d'Ida Frederikke Joachime de la famille Bülow.", "hyp-": "Johan Ludvig était le fils de Johan Georg Holstein, qui était un célèbre avocat et Ida Frederikke Joachime était une artiste renommée."}
# result text  {"hyp+": "De nombreuses lignes de bus partent de la Eddy Avenue adjacente ou de la rue Elizabeth ou de la Railway Square voisine.", "hyp-": "Les bus partent toujours de la même station."}
# result text  {"hyp+": "En 1886, Miles remplaça le général George Crook en tant que commandant des forces armées combattant Geronimo, un leader apache Chiricahua, dans le département de l'Arizona.", "hyp-": "En 1886, Miles devint gouverneur de l'Arizona."}
# result text  {"hyp+": "Au début de la saison, il faisait partie de l’alliance ``Moving Company’’, aux côtés de Howard, Jeremy, McCrae et Nick.", "hyp-": "Au début de l’année, il n’était pas un membre de l’alliance ``Moving Company’’, aux côtés de Howard, Jeremy, McCrae et Nick."}
# result text  {"hyp+": "Hardwick est apparu dans 'Coronation Street' en 1997 en tant que Naomi Russell et en 1998 en tant que Sheila Dixon.", "hyp-": "Hardwick a joué dans 'Coronation Street' en 1997 en tant que Naomi Russell et en 1998 en tant que Sheila Dixon."}
# result text  {"hyp+": "Les principes de base des théories du système peuvent être observés dans l'œuvre de Julian Steward ''Variation saisonnière des Esquimaux``, qui a ensuite été reprise dans le travail de Marcel Mauss.", "hyp-": "L'œuvre de Julian Steward ''Variation saisonnière des Esquimaux'' décrit les traditions des Inuits sans lien avec les théories du système."}
# result text  {"hyp+": "Il finit deux coups derrière Bubba Watson et Louis Oosthuizen et se lamenta de sa performance de putting comme la raison pour laquelle il n'a pas remporté le tournoi.", "hyp-": "Il a terminé en tête du classement grâce à ses performances de putt et a célébré sa victoire avec Bubba Watson et Louis Oosthuizen."}
# result text  {"hyp+": "Steve Whitley est apparu pour la première fois début juillet. Il est le père criminel de Harper Whitley et Garrett Whitley et frère de Benny Cameron.", "hyp-": "Steve Whitley est un joueur de baseball professionnel."}
# result text  {"hyp+": "Taisuke Sawachika a travaillé avec le guitariste et collaborateur de longue date Kudo sur la chanson ``Dose Nara''.", "hyp-": "Le guitariste Kudo a composé la chanson ``Dose Nara''."}
# result text  {"hyp+": "En 1974, le Laos a créé le fonds de la phase II avec l'aide de la Banque mondiale, des Nations Unies et de la Banque asiatique de développement.", "hyp-": "En 1974, le Laos a établi le fonds de la phase II sans aucune assistance extérieure."}
# result text  {"hyp+": "David Allan Coe a rejoint le groupe de tournée et d'enregistrement de Warren Haynes en 1980, lorsqu'il avait 20 ans.", "hyp-": "Warren Haynes a rejoint le groupe de tournée et d'enregistrement de David Allan Coe en 1980, lorsqu'il avait 20 ans."}
# result text  {"hyp+": "Il était marié à Elisabeth Young (1854 -- 1932) et était le père du magnat du navire Thomas Fearnley et du propriétaire foncier N. O. Young Fearnley.", "hyp-": "Il était un ingénieur naval renommé et inventeur de nouvelles technologies maritimes."}
# result text  {"hyp+": "Les suggestions de Met pour étendre de Paddington à South Kensington et à l'est de Moorgate à Tower Hill vers le sud ont été acceptées le 29 juillet 1864 et ont reçu l'approbation royale.", "hyp-": "Les suggestions de Met pour améliorer les liaisons de Paddington à South Kensington et au nord de Moorgate à Tower Hill ont été acceptées le 29 juillet 1864 et ont reçu l'approbation royale."}
# result text  {"hyp+": "Il était marié à Elisabeth Young (1854-1932) et était le père du magnat de la marine Thomas Fearnley et du propriétaire terrien N. O. Young Fearnley.", "hyp-": "Il était le père de Thomas Fearnley, un magnat de la marine, et le mari d'Elisabeth Young (1854-1932)."}
# result text  {"hyp+": "Le manuscrit a été ajouté à la liste des manuscrits du Nouveau Testament par Caspar René Gregory (278) et Frederick Henry Ambrose Scrivener (numéro 329).", "hyp-": "Les manuscrits ont été découverts par des archéologues français."}
# result text  {"hyp+": "43 personnes ont été sauvées; 40 dans les canots de sauvetage et trois ont été secourues par le 'Delaware'.", "hyp-": "Il y avait 43 personnes à bord, mais seulement 3 ont été secourues par le 'Delaware'."}
# result text  {"hyp+": "En 1781, le gouverneur de l'Illinois Thomas Jefferson a promu Clark au grade de général de brigade et lui a confié le commandement de toute la milice des comtés du Kentucky et de Virginie.", "hyp-": "En 1781, le gouverneur de l'Illinois Thomas Jefferson a nommé Clark au poste de gouverneur de l'Illinois."}
# result text  {"hyp+": "Il est près du Lough Corrib, sur la route N59 menant à Oughterard et Clifden, dans le Connemara.", "hyp-": "Il est situé à Dublin, la capitale de l'Irlande."}
# result text  {"hyp+": "Le personnage et le casting ont été révélés le 20 novembre, lorsque Fotiou est apparu dans une vidéo des coulisses vue par 'Neighbours' sur leur chaîne YouTube.", "hyp-": "Le personnage et le casting ont été révélés le 20 novembre, bien que Fotiou ait été absente dans une vidéo des coulisses vue par 'Neighbours' sur leur chaîne YouTube."}
# result text  {"hyp+": "La Coupe de l'UEFA 1973-74 a été remportée par Feyenoord Rotterdam contre Tottenham Hotspur 4 à 2.", "hyp-": "Le Feyenoord Rotterdam a remporté la Coupe UEFA 1973-74 contre Tottenham Hotspur 4 à 2."}
# result text  {"hyp+": "La dernière ligne du troisième verset a été modifiée pendant le règne d'Alexandre Ier de Yougoslavie en ``Kralja Aleksandra, Bože hrani ''.", "hyp-": "Le roi Alexandre Ier de Yougoslavie a changé sa propre dernière ligne du troisième verset en ``Kralja Aleksandra, Bože hrani ''. "}
# result text  {"hyp+": "Il a été sélectionné par les Philadelphia 76ers au 77e tour (7e choix global) de la draft NBA de 1967.", "hyp-": "Il jouait pour les Philadelphia 76ers dans le championnat de basket universitaire en 1967."}
# result text  {"hyp+": "Des marchands romains de la province de Nanjing ont visité Nanyue en 166, la Syrie en 226 et Luoyang en 284.", "hyp-": "Les marchands romains de la province de Nanjing n'ont jamais voyagé en Europe."}
# result text  {"hyp+": "Le 30 avril 1983, un C-311, affecté à la NAS Jacksonville, à Cuba, à la base navale de Guantanamo Bay, s'est écrasé entraînant la perte de 13 vies.", "hyp-": "En avril 1983, un C-311 s'est écrasé à Cuba."}
# result text  {"hyp+": "En 1924, il était porte-parole invité de l'ICM à Toronto, en 1932 à Zurich et à Oslo en 1936.", "hyp-": "En 1924, il était un touriste à Toronto, en 1932 à Zurich et à Oslo en 1936."}
# result text  {"hyp+": "Simyo appartient au groupe de télécommunications néerlandais KPN, après l'acquisition du reste d'E-Plus le 14 mars.", "hyp-": "Simyo est une entreprise française de télécommunications."}

# %%
fix_skipped_rows_manual("French", df_results_en_fr, skipped_rows_en_fr)
